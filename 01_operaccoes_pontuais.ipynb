# %% [markdown]
# <a href="https://colab.research.google.com/github/smlsilva/I.A-Inteligencia-Artificial/blob/master/01_operaccoes_pontuais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **`IMPORTANDO AS LIBRARIES`**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **`EXERCÍCIO 1`**

# %% [markdown]
# **FAZENDO O DOWNLOAD DAS IMAGENS**

# %%
# !wget 'https://s2.glbimg.com/LVi9qgQbSxlp5bhv9VGqsP-80nw=/620x413/e.glbimg.com/og/ed/f/original/2019/12/12/bullitefrentao.jpg'
# !wget 'https://i.pinimg.com/originals/3e/6b/69/3e6b69909923ebdb9a0f3ee3fc68f894.jpg'
# !wget 'https://www.automaistv.com.br/wp-content/uploads/2019/10/nissan_skyline_gt-r_v-spec_ii_9.jpg'

# %% [markdown]
# **CARREGANDO AS IMAGENS**

# %%
img1 = cv.imread('3e6b69909923ebdb9a0f3ee3fc68f894.jpg')
img2 = cv.imread('bullitefrentao.jpg')

img3 = cv.imread('nissan_skyline_gt-r_v-spec_ii_9.jpg')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)

# %% [markdown]
# **TRANSFORMANDO EM TONS DE CINZA**

# %%
img2 = cv.imread('bullitefrentao.jpg')
img2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

plt.figure(figsize=(20,15))
plt.subplot(231), plt.imshow(img2, cmap='gray')
plt.show()

array = np.array(img2.shape)
print('%i'%(array[0] * array[1]))
# Out:
# 256060

# %% [markdown]
# **TRANSFORMANDO A IMAGEM EM PRETO E BRANCO**

# %%
img3 = cv.imread('nissan_skyline_gt-r_v-spec_ii_9.jpg')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2GRAY)

plt.figure(figsize=(20, 15))
plt.subplot(231), plt.imshow(img3, cmap=plt.cm.binary)
plt.show()

# %% [markdown]
# **QUANTIDADE DE PIXELS**

# %%
img1 = cv.imread('3e6b69909923ebdb9a0f3ee3fc68f894.jpg')
array = np.array(img1.shape)
resul = array[0] * array[1]
print('%i' % resul)
# Out:
# 1024000

# %% [markdown]
# **AMOSTRAGEM DAS IMAGENS ORIGINAIS**

# %%
img1 = cv.imread('3e6b69909923ebdb9a0f3ee3fc68f894.jpg')
img2 = cv.imread('bullitefrentao.jpg')
img3 = cv.imread('nissan_skyline_gt-r_v-spec_ii_9.jpg')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)

plt.figure(figsize=(20, 15))
plt.subplot(231), plt.imshow(img1)
plt.subplot(232), plt.imshow(img2)
plt.subplot(233), plt.imshow(img3)
plt.show()

# %% [markdown]
# ### **`EXERCICIO 2`**

# %%
# !wget 'https://i.pinimg.com/originals/6f/b5/d5/6fb5d5fc1d588a0f1a75722e080af28d.png'
# !wget 'https://www.freepngimg.com/thumb/artwork/92724-fifa-medium-18-social-carnivoran-sized-to.png'
# !wget 'https://images-eu.ssl-images-amazon.com/images/I/61JIGx4HxfL.png'
# !wget 'https://muniztrader.com/wp-content/uploads/2018/02/cropped-Logo-Lobo.png'
# Out:
# --2020-10-03 12:04:18--  https://i.pinimg.com/originals/6f/b5/d5/6fb5d5fc1d588a0f1a75722e080af28d.png
# Resolving i.pinimg.com (i.pinimg.com)... 104.18.14.176, 104.18.15.176, 2a04:4e42:2f::84
# Connecting to i.pinimg.com (i.pinimg.com)|104.18.14.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 214302 (209K) [image/png]
# Saving to: ‘6fb5d5fc1d588a0f1a75722e080af28d.png’
#
# 6fb5d5fc1d588a0f1a7 100%[===================>] 209.28K  --.-KB/s    in 0.03s
#
# 2020-10-03 12:04:18 (7.56 MB/s) - ‘6fb5d5fc1d588a0f1a75722e080af28d.png’ saved [214302/214302]
#
# --2020-10-03 12:04:18--  https://www.freepngimg.com/thumb/artwork/92724-fifa-medium-18-social-carnivoran-sized-to.png
# Resolving www.freepngimg.com (www.freepngimg.com)... 88.99.162.33
# Connecting to www.freepngimg.com (www.freepngimg.com)|88.99.162.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139870 (137K) [image/png]
# ...

# %% [markdown]
# **CARREGANDO AS IMAGENS**

# %%
img1 = cv.imread('6fb5d5fc1d588a0f1a75722e080af28d.png')
img1 = cv.cvtColor(img1, cv.COLOR_BGR2RGB)

img2 = cv.imread('92724-fifa-medium-18-social-carnivoran-sized-to.png')
img2 = cv.cvtColor(img2, cv.COLOR_BGR2RGB)

img3 = cv.imread('61JIGx4HxfL.png')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)

img4 = cv.imread('cropped-Logo-Lobo.png')
img4 = cv.cvtColor(img4, cv.COLOR_BGR2RGB)

imagens = [img1, img2, img3, img4]

# %% [markdown]
# **TODAS AS IMAGENS**

# %%
for i in range(4):
  plt.figure(figsize=(15, 18))
  plt.subplot(4, 3, i + 1)
  plt.imshow(imagens[i])
  plt.show()

# %% [markdown]
# **CONSTRUINDO A IMAGEM 5**

# %%
img1 = cv.imread('6fb5d5fc1d588a0f1a75722e080af28d.png')
img2 = cv.imread('92724-fifa-medium-18-social-carnivoran-sized-to.png')
img3 = cv.imread('61JIGx4HxfL.png')
img3 = cv.cvtColor(img3, cv.COLOR_BGR2RGB)

img4 = cv.imread('cropped-Logo-Lobo.png')
img4 = cv.cvtColor(img4, cv.COLOR_BGR2RGB)

# FAZENDO AS OPERAÇÕES PONTUAIS ARITIMÉTICA
adicao = cv.add(img1,img2)
mult   = img3 * 0.5
sub    = cv.subtract(img4, img1)

# SOMANDO OS RESULTADOS
img  = cv.add(adicao,sub)
img5 = cv.add(img,img3)

# OPERAÇÃO DE NEGAÇÃO P/ CRIAR A IMAGEM-6
img6 = cv.bitwise_not(img1)

plt.figure(figsize=(20,8))
plt.subplot(241), plt.imshow(img5)
plt.subplot(242), plt.imshow(img6)
plt.show()

# %% [markdown]
# **HISTOGRAMA IMAGEM 6 E IMAGEM 1**

# %%
img1 = cv.imread('6fb5d5fc1d588a0f1a75722e080af28d.png')
img1 = cv.cvtColor(img1, cv.COLOR_BGR2RGB)
img6 = cv.bitwise_not(img1)

hist = cv.calcHist(img1,[0], None, [256], [0,256])
hist1 = cv.calcHist(img6, [0], None, [256], [0,256])

plt.figure(figsize=(40,20))
plt.subplot(241), plt.plot(hist,'--', color= 'red'), plt.xlim(0, 256)
plt.xlabel('Imagem_1')

plt.subplot(242), plt.plot(hist1,'--', color= 'blue'), plt.xlim(0, 256)
plt.xlabel('Imagem_6')


plt.show()

# %% [markdown]
# ### `EXERCÍCIO_3`

# %%
#!wget 'https://images.vexels.com/media/users/3/146098/preview2/e898edda54ad97422da77f799f8476ad-sinal-de-barras-de-cor-de-tv.jpg'

img = cv.imread('e898edda54ad97422da77f799f8476ad-sinal-de-barras-de-cor-de-tv.jpg')

# FAZENDO A CONVERSÃO
channel_one = cv.cvtColor(img, cv.COLOR_BGR2RGB)
channel_two = cv.cvtColor(img, cv.COLOR_BGR2RGB)
channel_three = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# EQUALIZAÇÃO DA IMAGEM, P/ CADA CANAL
channel_one[ :, :, 0] = cv.equalizeHist(img[ :, :, 0])
channel_two[ :, :, 1] = cv.equalizeHist(img[ :, :, 0])
channel_three[ :, :, 2] = cv.equalizeHist(img[ :, :, 1])

one = cv.cvtColor(channel_one, cv.COLOR_RGB2BGR)
two = cv.cvtColor(channel_two, cv.COLOR_RGB2BGR)
three = cv.cvtColor(channel_three, cv.COLOR_RGB2BGR)

plt.figure(figsize=(20,15))

plt.subplot(251), plt.imshow(one), plt.xlabel('EQUALIZAÇÃO_1')
plt.xticks([])
plt.yticks([])

plt.subplot(252), plt.imshow(two), plt.xlabel('EQUALIZAÇÃO_2')
plt.xticks([])
plt.yticks([])

plt.subplot(253), plt.imshow(three), plt.xlabel('EQUALIZAÇÃO_3')
plt.xticks([])
plt.yticks([])

plt.subplot(254), plt.imshow(img), plt.xlabel('IMAGEM ORIGINAL')
plt.xticks([])
plt.yticks([])

plt.show()

# %%
img = cv.imread('e898edda54ad97422da77f799f8476ad-sinal-de-barras-de-cor-de-tv.jpg')

# FAZENDO A CONVERSÃO P/ RGB
channel_one = cv.cvtColor(img, cv.COLOR_BGR2RGB)
channel_two = cv.cvtColor(img, cv.COLOR_BGR2RGB)
channel_three = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# EQUALIZAÇÃO DA IMAGEM, P/ CADA CANAL
channel_one[ :, :, 0] = cv.equalizeHist(img[ :, :, 1])
channel_two[ :, :, 1] = cv.equalizeHist(img[ :, :, 0])
channel_three[ :, :, 2] = cv.equalizeHist(img[ :, :, 1])

# CONVERTENDO PARA O PADRÃO RECONHECIDO PELO OPENCV
one = cv.cvtColor(channel_one, cv.COLOR_RGB2BGR)
two = cv.cvtColor(channel_two, cv.COLOR_RGB2BGR)
three = cv.cvtColor(channel_three, cv.COLOR_RGB2BGR)

plt.figure(figsize=(20,20))

plt.subplot(2, 3, 1), plt.hist(one.ravel(), 256, [0,256])
plt.subplot(2, 3 ,2), plt.hist(two.ravel(), 256, [0,256])
plt.subplot(2, 3, 3), plt.hist(three.ravel(), 256, [0,256])
plt.subplot(2, 3, 4), plt.hist(img.ravel(), 256, [0,256])
plt.show()
